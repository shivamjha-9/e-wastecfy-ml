# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamjha-9/e-wastecfy-ml/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tensorflow gradio

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-56b2cac2-a33c-458f-bd1a-8a4d30d7d0ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-56b2cac2-a33c-458f-bd1a-8a4d30d7d0ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip "E-Waste classification dataset (1).zip" -d dataset/
# Out:
# Archive:  E-Waste classification dataset (1).zip
#   inflating: dataset/modified-dataset/test/Battery/battery_106.jpg
#   inflating: dataset/modified-dataset/test/Battery/battery_128.jpg
#   inflating: dataset/modified-dataset/test/Battery/battery_148.jpg
#   inflating: dataset/modified-dataset/test/Battery/battery_152.jpg
#   inflating: dataset/modified-dataset/test/Battery/battery_174.jpg
#   inflating: dataset/modified-dataset/test/Battery/battery_177.jpg
#   inflating: dataset/modified-dataset/test/Battery/battery_190.jpg
#   inflating: dataset/modified-dataset/test/Battery/battery_192.jpg
#   inflating: dataset/modified-dataset/test/Battery/battery_211.jpg
#   inflating: dataset/modified-dataset/test/Battery/battery_22.jpg
#   inflating: dataset/modified-dataset/test/Battery/battery_24.jpg
#   inflating: dataset/modified-dataset/test/Battery/battery_241.jpg
#   inflating: dataset/modified-dataset/test/Battery/battery_242.jpg
# ...

# %%
# !find dataset/ -maxdepth 2 | sed -e 's/\.\///g'
# Out:
# dataset/
# dataset/modified-dataset
# dataset/modified-dataset/train
# dataset/modified-dataset/val
# dataset/modified-dataset/test

# %%
# !find dataset/modified-dataset/ -maxdepth 2 | sed -e 's/\.\///g'
# Out:
# dataset/modified-dataset/
# dataset/modified-dataset/train
# dataset/modified-dataset/train/Battery
# dataset/modified-dataset/train/Mobile
# dataset/modified-dataset/train/Keyboard
# dataset/modified-dataset/train/Washing Machine
# dataset/modified-dataset/train/Printer
# dataset/modified-dataset/train/Mouse
# dataset/modified-dataset/train/PCB
# dataset/modified-dataset/train/Television
# dataset/modified-dataset/train/Player
# dataset/modified-dataset/train/Microwave
# dataset/modified-dataset/val
# dataset/modified-dataset/val/Battery
# dataset/modified-dataset/val/Mobile
# dataset/modified-dataset/val/Keyboard
# dataset/modified-dataset/val/Washing Machine
# dataset/modified-dataset/val/Printer
# dataset/modified-dataset/val/Mouse
# dataset/modified-dataset/val/PCB
# dataset/modified-dataset/val/Television
# dataset/modified-dataset/val/Player
# dataset/modified-dataset/val/Microwave
# dataset/modified-dataset/test
# dataset/modified-dataset/test/Battery
# ...

# %%
import tensorflow as tf
import os

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

base_dir = 'dataset/modified-dataset'
train_dir = os.path.join(base_dir, 'train')
val_dir   = os.path.join(base_dir, 'val')
test_dir  = os.path.join(base_dir, 'test')

# Verify everything is where it should be
print("Exists:", os.path.exists(train_dir), os.path.exists(val_dir), os.path.exists(test_dir))
# Out:
# Exists: True True True

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='categorical',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    val_dir,
    labels='inferred',
    label_mode='categorical',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    labels='inferred',
    label_mode='categorical',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 2400 files belonging to 10 classes.
# Found 300 files belonging to 10 classes.
# Found 300 files belonging to 10 classes.

# %%
print("Classes:", train_ds.class_names)  # Should list 10 class names
for imgs, labels in train_ds.take(1):
    print("Image batch shape:", imgs.shape)
    print("Label batch shape:", labels.shape)
# Out:
# Classes: ['Battery', 'Keyboard', 'Microwave', 'Mobile', 'Mouse', 'PCB', 'Player', 'Printer', 'Television', 'Washing Machine']
# Image batch shape: (32, 224, 224, 3)
# Label batch shape: (32, 10)

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.applications import EfficientNetV2B0
IMG_SIZE = (224, 224)
NUM_CLASSES = len(train_ds.class_names)  # Should be 10

# %%
base_model = EfficientNetV2B0(
    include_top=False,
    weights='imagenet',
    input_shape=IMG_SIZE + (3,),
    pooling='avg'  # adds a GlobalAveragePooling layer
)
base_model.trainable = False  # Freeze all base layers
# Out:
# ...
# 24274472/24274472 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
inputs = layers.Input(shape=IMG_SIZE + (3,))
x = base_model(inputs, training=False)
x = layers.Dropout(0.2)(x)
outputs = layers.Dense(NUM_CLASSES, activation='softmax')(x)
model = Model(inputs, outputs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
initial_epochs = 5
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=initial_epochs
)
# Out:
# Epoch 1/5
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 203s 2s/step - accuracy: 0.5443 - loss: 1.5702 - val_accuracy: 0.9467 - val_loss: 0.3219
# Epoch 2/5
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 171s 2s/step - accuracy: 0.9562 - loss: 0.2948 - val_accuracy: 0.9600 - val_loss: 0.1930
# Epoch 3/5
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.9584 - loss: 0.1921 - val_accuracy: 0.9667 - val_loss: 0.1539
# Epoch 4/5
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.9670 - loss: 0.1520 - val_accuracy: 0.9633 - val_loss: 0.1387
# Epoch 5/5
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 172s 2s/step - accuracy: 0.9746 - loss: 0.1255 - val_accuracy: 0.9767 - val_loss: 0.1231

# %%
base_model.trainable = True
for layer in base_model.layers[:-20]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_ft = model.fit(train_ds, validation_data=val_ds, epochs=3, initial_epoch=5)

# %%
test_metrics = model.evaluate(test_ds)
print("Test loss:", test_metrics[0], "Test accuracy:", test_metrics[1])
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.9507 - loss: 0.1881
# Test loss: 0.15365014970302582 Test accuracy: 0.9633333086967468
